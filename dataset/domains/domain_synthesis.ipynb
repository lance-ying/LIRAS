# %%
from openai import OpenAI
import base64
with open("../../../../openai.txt", "r") as f:
    api_key = f.read()
client = OpenAI(api_key=api_key)

def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')
    
# image_path = f"/Users/lance/Downloads/example.png"

# Getting the base64 string
# base64_image = encode_image(image_path)

with open("instructions_dkg_generic.txt", "r") as f:
    instructions_dkg = f.read()

instructions = instructions_dkg


response = client.responses.create(
  model="gpt-4o",
  input=[
    {
      "role": "user",
      "content": [
        {
          "type": "input_text",
          "text": instructions + "\n Please write a PDDL domain definition for this setup." + PDDL_instruction
        },
      ]
    }]
)

# %%
response
# Out:
# Response(id='resp_67e1a79186b48192a8986a0766624eef0a30baf5841a2e4b', created_at=1742841745.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4o-2024-08-06', object='response', output=[ResponseOutputMessage(id='msg_67e1a79215d481928ba3972e5f401b310a30baf5841a2e4b', content=[ResponseOutputText(annotations=[], text='```json\n{\n  "domain_name": "treasure_game",\n  "PDDL_domain": [\n    "(define (domain treasure_game)",\n    "    (:requirements :fluents :adl :typing)",\n    "    (:types",\n    "        gem key agent - object",\n    "    )",\n    "    (:predicates",\n    "        (has-gem ?a - agent ?g - gem)",\n    "        (has-key ?a - agent ?k - key)",\n    "        (door-locked ?d - door)",\n    "    )",\n    "    (:functions",\n    "        (xloc ?o - object) (yloc ?o - object) - integer",\n    "        (walls) - bit-matrix",\n    "        (terrain-white) - bit-matrix",\n    "    )",\n    "    (:action pickup-gem",\n    "     :parameters (?a - agent 
# ...
